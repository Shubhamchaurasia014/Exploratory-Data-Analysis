# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Bhawna\Downloads\student_habits_performance.csv")
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
# ...

# %%
df['parental_education_level'].unique()
# Out:
# array(['Master', 'High School', 'Bachelor', nan], dtype=object)

# %%
df['parental_education_level'] = df['parental_education_level'].fillna('No Education')

# %%
df.isnull().sum()
# Out:
# student_id                       0
# age                              0
# gender                           0
# study_hours_per_day              0
# social_media_hours               0
# netflix_hours                    0
# part_time_job                    0
# attendance_percentage            0
# sleep_hours                      0
# diet_quality                     0
# exercise_frequency               0
# parental_education_level         0
# internet_quality                 0
# mental_health_rating             0
# extracurricular_participation    0
# exam_score                       0
# dtype: int64

# %%
df.groupby(df['gender'])['student_id'].count()
# Out:
# gender
# Female    481
# Male      477
# Other      42
# Name: student_id, dtype: int64

# %%
df[df['age'].isin([17,24])].groupby(['age'])['student_id'].count()
# Out:
# age
# 17    133
# 24    134
# Name: student_id, dtype: int64

# %%
avg_study = np.average(df['study_hours_per_day'])
print(avg_study)
# Out:
# 3.5501000000000005

# %%
df.groupby(df['study_hours_per_day'] >5)['student_id'].count()
# Out:
# study_hours_per_day
# False    845
# True     155
# Name: student_id, dtype: int64

# %%
df.groupby(['part_time_job'])['exam_score'].median()
# Out:
# part_time_job
# No     70.6
# Yes    69.2
# Name: exam_score, dtype: float64

# %%
avg_social_media = np.mean(df['social_media_hours'])
print(avg_social_media)
# Out:
# 2.5055

# %%
df.groupby(['gender'])['social_media_hours'].mean()
# Out:
# gender
# Female    2.503950
# Male      2.499371
# Other     2.592857
# Name: social_media_hours, dtype: float64

# %%
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
df['age_group'] = np.where(df['age']<20,"Under 20","Above 20")

# %%
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
df.isnull().sum()
# Out:
# student_id                       0
# age                              0
# gender                           0
# study_hours_per_day              0
# social_media_hours               0
# netflix_hours                    0
# part_time_job                    0
# attendance_percentage            0
# sleep_hours                      0
# diet_quality                     0
# exercise_frequency               0
# parental_education_level         0
# internet_quality                 0
# mental_health_rating             0
# extracurricular_participation    0
# exam_score                       0
# age_group                        0
# dtype: int64

# %%
df.groupby(['age_group'])['social_media_hours'].median()
# Out:
# age_group
# Above 20    2.4
# Under 20    2.5
# Name: social_media_hours, dtype: float64

# %%
df.groupby(df['sleep_hours']<5)['social_media_hours'].mean()
# Out:
# sleep_hours
# False    2.496857
# True     2.576147
# Name: social_media_hours, dtype: float64

# %%
df.groupby(['parental_education_level'])['exam_score'].mean()
# Out:
# parental_education_level
# Bachelor        70.272571
# High School     69.547194
# Master          68.086826
# No Education    70.034066
# Name: exam_score, dtype: float64

# %%
df[df['extracurricular_participation'] == "Yes"]['mental_health_rating'].mean()
# Out:
# np.float64(5.418238993710692)

# %%
df.describe()
# Out:
#              age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  1000.0000           1000.00000         1000.000000    1000.000000
# mean     20.4980              3.55010            2.505500       1.819700
# std       2.3081              1.46889            1.172422       1.075118
# min      17.0000              0.00000            0.000000       0.000000
# 25%      18.7500              2.60000            1.700000       1.000000
# 50%      20.0000              3.50000            2.500000       1.800000
# 75%      23.0000              4.50000            3.300000       2.525000
# max      24.0000              8.30000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count            1000.000000  1000.000000         1000.000000
# mean               84.131700     6.470100            3.042000
# std                 9.399246     1.226377            2.025423
# ...
